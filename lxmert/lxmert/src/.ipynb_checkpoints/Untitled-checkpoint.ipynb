# %%
from lxmert_lrp import LxmertForQuestionAnswering as LxmertForQuestionAnsweringLRP
from src.tasks import vqa_data
from src.modeling_frcnn import GeneralizedRCNN
import src.vqa_utils as utils
from src.processing_image import Preprocess
from transformers import LxmertTokenizer
from src.huggingface_lxmert import LxmertForQuestionAnswering

from tqdm import tqdm
from src.ExplanationGenerator import GeneratorOurs, GeneratorBaselines
import random
import cv2

COCO_VAL_PATH = '/media/data2/hila_chefer/env_MMF/datasets/coco/subset_val/images/val2014/'

OBJ_URL = "https://raw.githubusercontent.com/airsplay/py-bottom-up-attention/master/demo/data/genome/1600-400-20/objects_vocab.txt"
ATTR_URL = "https://raw.githubusercontent.com/airsplay/py-bottom-up-attention/master/demo/data/genome/1600-400-20/attributes_vocab.txt"
VQA_URL = "https://raw.githubusercontent.com/airsplay/lxmert/master/data/vqa/trainval_label2ans.json"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-b03239bcd702> in <module>
# ----> 1 from lxmert_lrp import LxmertForQuestionAnswering as LxmertForQuestionAnsweringLRP
#       2 from src.tasks import vqa_data
#       3 from src.modeling_frcnn import GeneralizedRCNN
#       4 import src.vqa_utils as utils
#       5 from src.processing_image import Preprocess
#
# /media/data2/hila_chefer/lxmert/lxmert/src/lxmert_lrp.py in <module>
#      25 from torch import nn
#      26 from torch.nn import CrossEntropyLoss, SmoothL1Loss
# ---> 27 from src.layers import *
#      28 from transformers.file_utils import (
#      29     ModelOutput,
#
# ModuleNotFoundError: No module named 'src'
